# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Must include runtime, memory size, timeout, and basic structure for AWS Lambda configuration"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Evaluation Criteria:
<solution_criteria>
{test_case["solution_criteria"]}
</solution_criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\n\npolicy = {\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [\n        {\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"s3:GetObject\",\n                \"s3:GetObjectVersion\"\n            ],\n            \"Resource\": \"arn:aws:s3:::**/logs/*\"\n        },\n        {\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"s3:ListBucket\"\n            ],\n            \"Resource\": \"arn:aws:s3:::*\",\n            \"Condition\": {\n                \"StringLike\": {\n                    \"s3:prefix\": \"logs/*\"\n                }\n            }\n        }\n    ]\n}\n\nprint(json.dumps(policy, indent=2))\n",
#     "test_case": {
#       "task": "Create an IAM policy document that allows read-only access to S3 bucket objects with a specific prefix 'logs/'",
#       "format": "json",
#       "solution_criteria": "Must include Version, Statement array with Effect, Action, Resource, and Principal fields. Should restrict actions to s3:GetObject and s3:ListBucket. Resource ARN must include the 'logs/' prefix constraint."
#     },
#     "score": 2.5,
#     "reasoning": "The solution demonstrates good understanding of IAM policy structure and read-only S3 access patterns, but contains critical ARN syntax errors that would prevent the policy from functioning correctly. The resource ARNs must reference a specific bucket name and follow proper S3 ARN format. Additionally, the Principal field is omitted, though this may be acceptable if intended as an inline policy rather than a resource-based policy."
#   },
#   {
#     "output": "\nimport re\n\ndef validate_s3_bucket_name(name: str) -> bool:\n    pattern = r'^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$'\n    return bool(re.match(pattern, name))\n",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS S3 bucket name according to AWS naming rules (3-63 characters, lowercase letters, numbers, hyphens only, must start and end with letter or number)",
#       "format": "python",
#       "solution_criteria": "Must be a single function that returns boolean. Should validate length, allowed characters, and start/end character constraints. Function name should be descriptive."
#     },
#     "score": 9.0,
#     "reasoning": "The solution correctly implements all technical requirements specified in the task. The regex pattern properly enforces the 3-63 character length constraint, character set restrictions, and start/end character rules. However, the implementation lacks robustness against edge cases (non-string inputs) and documentation that would be expected in production code. Adding basic type checking and a docstring would make this enterprise-ready."
#   },
#   {
#     "output": "\n^/aws/[a-zA-Z0-9/_-]+$\n",
#     "test_case": {
#       "task": "Create a regular expression to match valid AWS CloudWatch log group names (format: /aws/service/resource-name, alphanumeric, hyphens, underscores, forward slashes allowed)",
#       "format": "regex",
#       "solution_criteria": "Must match valid log group names starting with /aws/. Should allow alphanumeric characters, hyphens, underscores, and forward slashes. Must reject names with invalid characters or improper format."
#     },
#     "score": 8.0,
#     "reasoning": "The regex correctly captures the basic requirements of matching /aws/ prefix and allowing valid characters. However, it lacks refinement for AWS-specific constraints like preventing consecutive special characters, enforcing meaningful names after the prefix, and respecting the 256-character limit. A more robust pattern would be: ^/aws/[a-zA-Z0-9]([a-zA-Z0-9/_-]{0,254}[a-zA-Z0-9])?$ to ensure names don't end with special characters and stay within length limits."
#   }
# ]
